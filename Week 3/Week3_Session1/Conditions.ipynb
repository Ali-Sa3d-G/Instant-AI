# %% [markdown]
# Part 1: If Statements
#
# Exercise 1 (Easy):
# Write a program that takes a number n from the user and prints:
#
# "Positive" if the number is greater than 0
#
# "Negative" if the number is less than 0
#
# "Zero" if the number is 0

# %%
x=int(input())
if x>0:
    print("Positive")

elif x<0:
    print("Negative")
else:
    print("zero")
# Out:
# zero

# %% [markdown]
# Exercise 2 (Easy):
# Ask the user for their age and print:
#
# "Child" if age < 13
#
# "Teen" if 13 ≤ age ≤ 19
#
# "Adult" if age > 19

# %%
age=int(input())
if age<13:
    print("child")

elif 13<=age<=19: # age >=13 and age <=19
    print("Teen")

else:
    print("Adult")
# Out:
# child

# %% [markdown]
# Exercise 3 (Easy-Medium):
# Write a program that takes a number from the user and prints "Even" if it is even or "Odd" if it is odd.

# %%
n=int(input())
if n%2==0:
    print("Even")

else:
    print("odd")
# Out:
# odd

# %% [markdown]
# Exercise 4 (Medium):
# Ask the user to input three numbers and print the largest one using if-elif-else.

# %%
a=int(input())
b=int(input())
c=int(input())
if a>=b and a>=c: # 4 4 2
    print(f"A is the Largest {a}")

elif b>=a and b>=c:
    print("B is the Largest")

elif c>=a and c>=b:
    print("C is the Largest")
# Out:
# A is the Largest 7

# %% [markdown]
# Exercise 5 (Medium):
# Create a simple password check:
#
# Ask the user to input a password.
#
# If the password is "Python123" print "Access granted"
#
# Otherwise, print "Access denied"

# %%
password=input()
if password=="Python123":
    print("Access Granted")

else :
    print("Acess Denied")
# Out:
# Access Granted

# %% [markdown]
# Exercise 6 (Easy):
# Write a program that takes a number from 1 to 7 and prints the corresponding day of the week using match-case:
# 1 → Monday, 2 → Tuesday, …, 7 → Sunday

# %%
day=int(input())
match day:
    case 1:
        print("Monday")

    case 2:
        print("Tuesday")

    case 3:
        print("Wedensday")


    case 4:
        print("Thurasday")



    case 5:
        print("Friday")



    case 6:
        print("Saturday")

    case 7:
        print("Sunday")

    case _:
        print("Invalid Number")
# Out:
# Invalid Number

# %% [markdown]
# Exercise 7 (Easy-Medium):
# Ask the user to input a single letter and print:
#
# "Vowel" if it is a vowel (a, e, i, o, u)
#
# "Consonant" if it is not a vowel

# %%
letter=input().lower()
match letter:
    case 'a':
        print("Vowel")
    case 'e':
        print("Vowel")
    case 'i':
        print("Vowel")
    case 'o':
        print("Vowel")
    case 'u':
        print("Vowel")
    case _:
        print("Not Vowel")
# Out:
# Vowel

# %%
letter=input().lower()
match letter:
    case 'a'|'e'|'i'|'o'|'u':
        print("Vowel")
    case _:
        print("Not Vowel")
# Out:
# Vowel

# %%
letter=input().lower()
s="aeiou"
if letter in s:
    print("Vowel")

else:
    print("Not Vowel")
# Out:
# Not Vowel

# %%
letter=input().lower()
if letter in s:
    print("Vowel")

else:
    print("Not Vowel")

# %%
s="aeiou"
print('o' in s)
# Out:
# True

# %% [markdown]
# Exercise 8 (Medium):
# Ask the user to input a color and print:
#
# "Primary Color" if it is "red", "blue", or "green"
#
# "Other Color" for any other color"

# %%
color =input().lower()
l=["red","blue","green"]
if color in l:
    print("Primary color")
else:
    print("Other color")

# %%
color =input().lower() 
match color:
    case "red"|"green"|"blue":
                print("primary color")
    case _:
                print("Other color")
# Out:
# primary color

# %% [markdown]
# Exercise 9 (Medium-Hard):
# Write a simple calculator:
#
# Ask the user to input an operator (+, -, *, /) and two numbers.
#
# Use match-case to perform the operation and print the result.

# %%
a=int(input())
b=int(input())
op=input()
match op:
    case '+':
        print(a+b)
    case '-':
        print(a-b)
    case '*':
        print(a*b)

    case '/':
        if b==0:
            print("Invalid div by zero")

        else:
            print(a/b)

    case _:
        print("Invalid Operator")
# Out:
# 1.0

# %% [markdown]
# Exercise 10 (Hard):
# Traffic light program:
#
# Ask the user to input a traffic light symbol (R, Y, G)
#
# Print:
#
# "Stop" for R
#
# "Ready" for Y
#
# "Go" for G
#
# "Invalid" for any other input

# %%
s=input()
print(f"Hello, {s}")

# %%
9
a

# %%
letter=input()
if letter.isalpha():
    print("ALPHA")
    if letter.islower():
        print("IS SMALL")
    else:
        print("IS CAPITAL")

else:
    print("IS DIGIT")
# Out:
# ALPHA
# IS SMALL

# %%
letter=input()
if letter.isupper():
    print(letter.lower())

else:
    print(letter.upper())
# Out:
# A

# %% [markdown]
# ## Level 1 – Very Basic (Understanding the Loop)

# %% [markdown]
# Write a program that prints numbers from 1 to 10 using a for loop.

# %% [markdown]
# Write a program that prints all even numbers from 1 to 20.

# %% [markdown]
# Write a program that prints each character in the string:
#
# "Assiut University"

# %% [markdown]
# Write a program that prints the multiplication table of 5 (from 1 to 10).

# %% [markdown]
# Level 2 – Working with Lists
# 5️⃣
#
# Write a program that:
#
# Takes a list of numbers
#
# Prints only numbers greater than 10

# %% [markdown]
# Write a program that:
#
# Calculates the sum of elements in a list using a for loop

# %% [markdown]
# Write a program that:
#
# Counts how many odd numbers exist in a list

# %% [markdown]
# Level 3 – Nested Loops & Logic
# Write a program that:
#
# Prints this pattern using nested for loops:

# %%
'''
*
**
***
****
*****
'''
# Out:
# '\n*\n**\n***\n****\n*****\n'

# %% [markdown]
# Write a program that:
#
# Prints a 5×5 square of stars:

# %%
'''
*****
*****
*****
*****
*****

'''

# %% [markdown]
# Write a program that:
#
# Finds the largest number in a list using a for loop (no max)

# %% [markdown]
# Level 4 – Advanced Thinking with for Loop
#
# Write a program that:
#
# Checks if a number is prime using a for loop

# %% [markdown]
# Write a program that:
#
# Takes an integer number from the user
#
# Calculates its factorial using a for loop
#
# Prints the result
#
# Example:
#
# Input → 5
#
# Output → 120
